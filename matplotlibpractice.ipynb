# %%
import matplotlib.pyplot as plt
import numpy as np
import time

# %%
x=[4,7,8,9,11,5]
y=[13,23,5,7,9,6]
player=['virat','dhoni','vijay','dhawan']
runs=[120,44,77,33]
exp=[0.1,0,0,1]

# %%
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.plot(x,y)

# %%
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.grid(color='orange')
plt.scatter(x,y)
plt.plot(x,y)

# %%
np.full((3,6),9)
# Out:
# array([[9, 9, 9, 9, 9, 9],
#        [9, 9, 9, 9, 9, 9],
#        [9, 9, 9, 9, 9, 9]])

# %%
plt.pie(runs,labels=player,explode=exp)
# Out:
# ([<matplotlib.patches.Wedge at 0x7fde7b523390>,
#   <matplotlib.patches.Wedge at 0x7fde7b523828>,
#   <matplotlib.patches.Wedge at 0x7fde7b523cc0>,
#   <matplotlib.patches.Wedge at 0x7fde7b4b0198>],
#  [Text(0.23242130759939578, 1.177276660676575, 'virat'),
#   Text(-1.092777526229224, -0.12584624812976195, 'dhoni'),
#   Text(-0.07561366497327134, -1.0973980926123892, 'vijay'),
#   Text(1.9514651661827336, -0.7757471915356162, 'dhawan')])

# %%
plt.pie(runs,labels=player,explode=exp,autopct='%f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7fde7b374e48>,
#   <matplotlib.patches.Wedge at 0x7fde7b382518>,
#   <matplotlib.patches.Wedge at 0x7fde7b382ba8>,
#   <matplotlib.patches.Wedge at 0x7fde7b38d278>],
#  [Text(0.23242130759939578, 1.177276660676575, 'virat'),
#   Text(-1.092777526229224, -0.12584624812976195, 'dhoni'),
#   Text(-0.07561366497327134, -1.0973980926123892, 'vijay'),
#   Text(1.9514651661827336, -0.7757471915356162, 'dhawan')],
#  [Text(0.13557909609964752, 0.686744718728002, '43.795621%'),
#   Text(-0.596060468852304, -0.06864340807077923, '16.058394%'),
#   Text(-0.041243817258148, -0.5985807777885759, '28.102189%'),
#   Text(1.4868306028058922, -0.5910454792652314, '12.043796%')])
